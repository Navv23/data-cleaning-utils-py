# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/kaggle/input/mobiles-on-flipkart-for-the-price-range-of-1020k/Flipart_Mobiles-10-20k.csv")

# %% [markdown]
# ## Initial Investigations

# %%
df.head(3)
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://www.flipkart.com/realme-9i-prism-black...
# 1           1  https://www.flipkart.com/realme-9i-prism-blue-...
# 2           2  https://www.flipkart.com/realme-9i-prism-blue-...
#
#                              name    price  rating  \
# 0  realme 9i (Prism Black, 64 GB)  ₹10,499     4.5
# 1   realme 9i (Prism Blue, 64 GB)  ₹10,499     4.5
# 2  realme 9i (Prism Blue, 128 GB)  ₹11,499     4.5
#
#                     rating&review_c  \
# 0  1,10,702 Ratings & 6,523 Reviews
# 1  1,10,702 Ratings & 6,523 Reviews
# 2  1,10,702 Ratings & 6,523 Reviews
#
#                                          description
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....
# 1  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....
# 2  4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...

# %%
df.shape
# Out:
# (2088, 7)

# %% [markdown]
# ## Cleaning & Sorting

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# link               0
# name               0
# price              0
# rating             0
# rating&review_c    0
# description        0
# dtype: int64

# %%
df.drop_duplicates(subset='description', inplace=True)

# %%
df.shape
# Out:
# (28, 6)

# %%
df['name'].unique()
# Out:
# array(['realme 9i (Prism Black, 64 GB)', 'realme 9i (Prism Blue, 128 GB)',
#        'realme 9i (Prism Black, 128 GB)',
#        'MOTOROLA g52 (Charcoal Grey, 128 GB)',
#        'realme 9 (Meteor Black, 128 GB)',
#        'POCO M4 Pro 5G (Cool Blue, 128 GB)',
#        'realme 9 (Sunburst Gold, 128 GB)',
#        'POCO M4 5G (Power Black, 128 GB)',
#        'POCO M4 Pro (Cool Blue, 64 GB)',
#        'POCO M4 Pro (Power Black, 128 GB)',
#        'MOTOROLA G60 (Moonless, 128 GB)',
#        'vivo T1 44W (Midnight Galaxy, 128 GB)',
#        'POCO M4 Pro 5G (Power Black, 64 GB)',
#        'SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)',
#        'SAMSUNG GALAXY M13 (Midnight Blue, 64 GB)',
#        'realme 10 Pro 5G (Dark Matter, 128 GB)',
#        'vivo T1X (Space Blue, 64 GB)', 'OPPO K10 (Blue Flame, 128 GB)',
#        'POCO M4 5G (Power Black, 64 GB)',
#        'MOTOROLA G62 5G (Midnight Gray, 128 GB)',
#        'POCO X4 Pro 5G (Laser Black, 128 GB)',
#        'vivo T1X (Space Blue, 128 GB)',
#        'vivo T1 5G (Rainbow Fantasy, 128 GB)',
#        'REDMI Note 10T 5G (Mint Green, 128 GB)'], dtype=object)

# %%
df['company'] = df['name'].apply(lambda x:x.split(" ")[0])

# %%
df['model'] = df['name'].apply(lambda x:x.split(" ")[1])

# %%
df.head(3)
# Out:
#                                                 link  \
# 0  https://www.flipkart.com/realme-9i-prism-black...
# 2  https://www.flipkart.com/realme-9i-prism-blue-...
# 3  https://www.flipkart.com/realme-9i-prism-black...
#
#                               name    price  rating  \
# 0   realme 9i (Prism Black, 64 GB)  ₹10,499     4.5
# 2   realme 9i (Prism Blue, 128 GB)  ₹11,499     4.5
# 3  realme 9i (Prism Black, 128 GB)  ₹13,499     4.5
#
#                     rating&review_c  \
# 0  1,10,702 Ratings & 6,523 Reviews
# 2  1,10,702 Ratings & 6,523 Reviews
# 3    25,154 Ratings & 1,503 Reviews
#
#                                          description company model
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....  realme    9i
# 2  4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...  realme    9i
# 3  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...  realme    9i

# %%
df['rom'] = df['name'].apply(lambda x:x.split(",")[1])

# %%
df['rom'] = df['rom'].str.replace(")","", regex=False)

# %%
df['price'] = df['price'].str.replace("₹","", regex=False)

# %%
df.head(3)
# Out:
#                                                 link  \
# 0  https://www.flipkart.com/realme-9i-prism-black...
# 2  https://www.flipkart.com/realme-9i-prism-blue-...
# 3  https://www.flipkart.com/realme-9i-prism-black...
#
#                               name   price  rating  \
# 0   realme 9i (Prism Black, 64 GB)  10,499     4.5
# 2   realme 9i (Prism Blue, 128 GB)  11,499     4.5
# 3  realme 9i (Prism Black, 128 GB)  13,499     4.5
#
#                     rating&review_c  \
# 0  1,10,702 Ratings & 6,523 Reviews
# 2  1,10,702 Ratings & 6,523 Reviews
# 3    25,154 Ratings & 1,503 Reviews
#
#                                          description company model      rom
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....  realme    9i    64 GB
# 2  4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...  realme    9i   128 GB
# 3  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...  realme    9i   128 GB

# %%
df['ratings'] = df['rating&review_c'].apply(lambda x: x.split('&')[0])
df['reviews'] = df['rating&review_c'].apply(lambda x: x.split('&')[1])

# %%
df['ratings'] = df['ratings'].str.replace("Ratings","", regex=False)
df['reviews'] = df['reviews'].str.replace("Reviews","", regex=False)

# %%
df['ram'] = df['description'].apply(lambda x:x.split("|")[0])
df['rom'] = df['description'].apply(lambda x:x.split("|")[1])

# %%
df.head(3)
# Out:
#                                                 link  \
# 0  https://www.flipkart.com/realme-9i-prism-black...
# 2  https://www.flipkart.com/realme-9i-prism-blue-...
# 3  https://www.flipkart.com/realme-9i-prism-black...
#
#                               name   price  rating  \
# 0   realme 9i (Prism Black, 64 GB)  10,499     4.5
# 2   realme 9i (Prism Blue, 128 GB)  11,499     4.5
# 3  realme 9i (Prism Black, 128 GB)  13,499     4.5
#
#                     rating&review_c  \
# 0  1,10,702 Ratings & 6,523 Reviews
# 2  1,10,702 Ratings & 6,523 Reviews
# 3    25,154 Ratings & 1,503 Reviews
#
#                                          description company model  \
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....  realme    9i
# 2  4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...  realme    9i
# 3  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...  realme    9i
#
#             rom     ratings  reviews        ram
# 0    64 GB ROM   1,10,702     6,523   4 GB RAM
# 2   128 GB ROM   1,10,702     6,523   4 GB RAM
# 3   128 GB ROM     25,154     1,503   6 GB RAM

# %%
df['color'] = df['name'].apply(lambda x:x.split("(")[1])
df['color1'] = df['color'].apply(lambda x:x.split(",")[0])

# %%
df.drop(['rating&review_c','name','description','color'],axis=1, inplace=True)

# %%
df1 = df[df['rating']>=4.5]

# %%
df1.head()
# Out:
#                                                  link   price  rating company  \
# 0   https://www.flipkart.com/realme-9i-prism-black...  10,499     4.5  realme
# 2   https://www.flipkart.com/realme-9i-prism-blue-...  11,499     4.5  realme
# 3   https://www.flipkart.com/realme-9i-prism-black...  13,499     4.5  realme
# 19  https://www.flipkart.com/vivo-t1-44w-midnight-...  14,499     4.5    vivo
# 30  https://www.flipkart.com/vivo-t1x-space-blue-6...  11,999     4.5    vivo
#
#    model                                                rom     ratings  \
# 0     9i                                         64 GB ROM   1,10,702
# 2     9i                                        128 GB ROM   1,10,702
# 3     9i                                        128 GB ROM     25,154
# 19    T1                                        128 GB ROM     72,246
# 30   T1X   64 GB ROM16.71 cm (6.58 inch) Full HD+ Displa...    64,576
#
#     reviews        ram           color1
# 0    6,523   4 GB RAM       Prism Black
# 2    6,523   4 GB RAM        Prism Blue
# 3    1,503   6 GB RAM       Prism Black
# 19   5,278   4 GB RAM   Midnight Galaxy
# 30   3,659   4 GB RAM        Space Blue
